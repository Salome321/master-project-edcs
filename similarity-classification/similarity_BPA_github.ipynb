# %%
from rdkit import Chem
from rdkit import DataStructs
from rdkit.Chem.Fingerprints import FingerprintMols
import pandas as pd

# %%
# read the csv
df = pd.read_csv('DEDuCT_ChemicalBasicInformation.csv')

# %%
# proof and make a list of SMILES
df_smiles = df['SMILES (Canonical)']
c_smiles = []
for ds in df_smiles:
    try:
        cs = Chem.CanonSmiles(ds)
        c_smiles.append(cs)
    except:
        print('Invalid SMILES:', ds)
print(len(c_smiles), len(df_smiles))
# Out:
# 686 686

# %%
# make a list of mols
ms = [Chem.MolFromSmiles(x) for x in c_smiles]

# make a list of fingerprints (fp)
fps = [FingerprintMols.FingerprintMol(x) for x in ms]

# Make a query_fingerprint for the reference molecule of interest eg. Bisphenol A (BPA) or estradiol
estradiol_SMILES = 'CC12CCC3C(C1CCC2O)CCC4=C3C=CC(=C4)O'
BPA_SMILES = 'CC(C)(C1=CC=C(C=C1)O)C2=CC=C(C=C2)O'
query_ms = Chem.MolFromSmiles(BPA_SMILES)
query_fp = FingerprintMols.FingerprintMol(query_ms)

# ta is the list of targets, sim is the similarity between the target and the reference molecule of interest chosen previously
ta, sim = [], []
for n in range(len(fps)):
    s = DataStructs.TanimotoSimilarity(query_fp, fps[n])
    ta.append(c_smiles[n])
    sim.append(s)
print(ta, sim)

# Build the dataframe and sort it according to similarity with the reference molecule
d = {'Target':ta, 'Similarity':sim}
df_scores = pd.DataFrame(data=d)
df_final = df_scores.sort_values('Similarity', ascending=False)
print(df_final)

# save as csv
df_final.to_csv('Classified.csv', index=False, sep=',')
# Out:
# ['ClC1C(Cl)C(Cl)C(Cl)C(Cl)C1Cl', 'Nc1n[nH]c(=S)s1.Nc1n[nH]c(=S)s1.[Cu]', 'ClC1C(Cl)C(Cl)C(Cl)C(Cl)C1Cl', 'COc1cc(-c2cc(=O)c3ccccc3o2)ccc1[N+](=O)[O-]', 'O=P(O)(O)OCCC(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)F', 'Cc1cc(O)c2c(c1)C(=O)c1cccc(O)c1C2=O', '[Cu+2].[S-]c1nnc(NCNc2nnc([S-])s2)s1', 'N#CC(Cc1ccc(O)cc1)c1ccc(O)cc1', 'Oc1ccc(C2(c3ccc(O)cc3)CC3CC2C2CCCC32)cc1', '[Cl-].[Cl-].[Mn+2]', 'CC(C)C(C(=O)OC(C#N)c1cccc(Oc2ccccc2)c1)c1ccc(Cl)cc1', 'NC(=O)c1cnccn1', 'CC12CCC3c4ccc(O)cc4CC(CCCCCCCCCS(=O)CCCC(F)(F)C(F)(F)F)C3C1CCC2O', 'FC(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)I', 'Brc1cc(-c2cc(Br)c(Br)c(Br)c2)cc(Br)c1Br', 'Oc1ccc(-c2c(Cl)cc(Cl)cc2Cl)cc1', 'O=S(=O)(O)O.[Fe]', 'CN(C)c1ccc(C(O)(c2ccccc2)c2ccc(N(C)C)cc2)cc1', 'CNc1c(C)n(C)n(-c2ccccc2)c1=O', 'CC(=O)C1(O)CCC2C3CC(C)C4=CC(=O)CCC4(C)C3CCC21C', 'Clc1cc2c(Cl)c(Cl)c(Cl)c(Cl)c2cc1Cl', 'CS(=O)(=O)c1cc(Cl)cc(-c2cc(Cl)c(Cl)cc2Cl)c1Cl', 'NC(Cc1ccc(O)c(-c2cc(CC(N)C(=O)O)ccc2O)c1)C(=O)O', 'Brc1ccc(-c2ccc(Br)c(Br)c2)cc1Br', 'Brc1cc(Br)c(-c2cc(Br)c(Br)c(Br)c2)cc1Br', 'CS(=O)(=O)c1cc(Cl)cc(-c2ccc(Cl)c(Cl)c2Cl)c1Cl', 'CS(=O)(=O)c1cc(Cl)c(-c2cc(Cl)c(Cl)cc2Cl)cc1Cl', 'CS(=O)(=O)c1cc(Cl)c(-c2ccc(Cl)c(Cl)c2Cl)cc1Cl', 'COc1c(Oc2ccc(Br)cc2Br)cc(Br)c(Br)c1Br', 'Clc1cccc(Cl)c1', 'Brc1c(Br)c(Br)c(CCc2c(Br)c(Br)c(Br)c(Br)c2Br)c(Br)c1Br', 'CC(=O)[O-].CC(=O)[O-].[Cd+2]', 'COc1ccc(C(=CC(=O)N2CCOCC2)c2ccc(F)cc2)cc1OC', 'CN1CC(=O)N2C(Cc3c([nH]c4ccccc34)C2c2ccc3c(c2)OCO3)C1=O', 'c1ccc(C2CCC2c2ccccc2)cc1', 'CCc1cccc(C)c1N(C(=O)CCl)C(C)COC', 'OCC1CO1', 'C[Si]1(C)O[Si](C)(C)O[Si](C)(C)O[Si](C)(C)O1', 'CC(=O)[O-].CC(=O)[O-].[Zn+2]', 'CC12CCC3C(CCC4=C(O)C(=O)CCC43C)C1CCC2=O', 'Nc1c(N=Nc2ccc(-c3ccc(N=Nc4cc(S(=O)(=O)[O-])c5ccccc5c4N)cc3)cc2)cc(S(=O)(=O)[O-])c2ccccc12.[Na+].[Na+]', 'Cc1ccccc1', 'Clc1cc2c(cc1Cl)Oc1cc(Br)c(Cl)cc1O2', 'Cc1cc(Cl)cc2c1oc1cc(Cl)cc(Cl)c12', 'CS(=O)(=O)c1cc(Cl)cc(-c2cc(Cl)c(Cl)c(Cl)c2Cl)c1Cl', 'N#CN=C1SCCN1Cc1ccc(Cl)nc1', 'CC(Oc1cc(-c2cnn(C3CCNCC3)c2)cnc1N)c1c(Cl)ccc(F)c1Cl', 'CCCCC(CC)COC(=O)c1c(Br)c(Br)c(Br)c(Br)c1C(=O)OCC(CC)CCCC', 'O=C(c1ccc(O)cc1)c1ccc(F)cc1', 'O=c1cc(-c2ccccc2)oc2c1ccc1ccccc12', 'COC(=O)c1ccccc1C(=O)c1ccccc1', 'BrCC(Br)COc1c(Br)cc(Br)cc1Br', 'Cc1c(O)cccc1O', 'Clc1cc(Cl)c(Cl)c(Cl)c1Cl', 'CS(=O)(=O)c1cc(Cl)ccc1C(=C(Cl)Cl)c1ccc(Cl)cc1', 'CS(=O)(=O)c1cc(Cl)c(-c2cc(Cl)c(Cl)cc2Cl)c(Cl)c1Cl', 'CS(=O)(=O)c1cc(Cl)c(Cl)c(-c2ccc(Cl)c(Cl)c2Cl)c1Cl', 'CCCC(CCC)(c1ccc(O)cc1)c1ccc(O)cc1', 'c1ccc(C2CCC2c2ccccc2)cc1', 'CS(=O)(=O)c1cc(Cl)cc(-c2ccc(Cl)cc2Cl)c1Cl', 'CCCCCCCCCCCCCCCC1C(CP(=O)(O)O)OC(COC2OC(COC3(C(=O)O)CC(OC4(C(=O)O)CC(OC5(C(=O)O)CC(O)C(O)C(C(O)CO)O5)C(O)C(C(O)CO)O4)C(OC4OC(C(O)CO)C(OP(=O)(O)OP(=O)(O)OCCN)C(OC5OC(C(O)COC6OCC(O)(C(O)CO)C(O)C6O)C(OP(=O)(O)O)C(OC6OC(COC7OC(CO)C(O)C(O)C7O)C(O)C(OC7OC(CO)C(O)C(O)C7OC7OC(CO)C(OC8OC(CO)C(O)C(OC9OC(C)C(OC%10OC(CO)C(O)C(OC%11OC(C)C(O)CC%11O)C%10OC%10OC(CO)C(O)C(O)C%10O)C(O)C9O)C8O)C(O)C7OC7OC(CO)C(O)C(O)C7NC(C)=O)C6O)C5O)C4O)C(C(O)CO)O3)C(OP(=O)(O)O)C(OC(=O)CC(CCCCCCCCCCC)OC(=O)CCCCCCCCCCCCC)C2NC(=O)CC(CCCCCCCCCCC)OC(=O)CCCCCCCCCCC)C(O)C1OC(=O)CC(O)CCCCCCCCCCC', 'Oc1c(Oc2ccc(Br)cc2Br)cc(Br)c(Br)c1Br', 'Oc1ccc(Cc2ccc(O)cc2)cc1', 'COCC(=O)O', 'CCc1cc(CC)c2sc3ccccc3c(=O)c2c1', 'O=S1OCC2C(CO1)C1(Cl)C(Cl)=C(Cl)C2(Cl)C1(Cl)Cl', 'ClC1=C(Cl)C2(Cl)C3C4C=CC(C4)C3C1(Cl)C2(Cl)Cl', '[O-][Cl+3]([O-])([O-])[O-]', 'O=C(O)C(Br)Br', 'Cl[Sn](c1ccccc1)(c1ccccc1)c1ccccc1', 'CCCC[Sn](Cl)(Cl)CCCC', 'Cc1ccc(N(SC(F)(Cl)Cl)S(=O)(=O)N(C)C)cc1', 'O=C1OC2(c3ccccc31)c1cc(I)c([O-])c(I)c1Oc1c2cc(I)c([O-])c1I.[Na+].[Na+]', 'Clc1ccc(COC(Cn2ccnc2)c2ccc(Cl)cc2Cl)c(Cl)c1.[Ag]', 'Clc1ccc(C(c2ccccc2Cl)C(Cl)(Cl)Cl)cc1', 'CCNc1nc(NC(C)C)nc(SC)n1', 'CN1CCCC1=O', 'O=C(O)c1ccc(O)cc1', 'Oc1c(Cl)ccc(Cl)c1Cl', 'Oc1c(Cl)c(Cl)cc(Cl)c1Cl', 'C=C(Br)COc1c(Br)cc(Br)cc1Br', 'CCCCCCCCc1ccccc1O', 'CC12CCC3C(CCC4=CC(=O)C=CC43C)C1CCC(=O)O2', 'CCCCC(=O)OC1CCC2C3CCc4cc(O)ccc4C3CCC12C', 'CCC12COP(=O)(OC1)OC2', 'CCC(CO)NCCNC(CC)CO', 'C=Cc1ccc(Cl)cc1', 'Oc1ccc(C2CCCCC2)cc1', 'O=C(c1ccccc1)c1ccc(O)cc1', 'Brc1c(Br)c(Br)c(Oc2c(Br)c(Br)c(Br)c(Br)c2Br)c(Br)c1Br', 'CN(C ...

# %%
# Classified version of the Chemical Basic Information csv file
df_classified = pd.read_csv('DEDuCT_ChemicalBasicInformation.csv')
df_classified['Similarity'] = sim
df_classified = df_classified.sort_values('Similarity', ascending=False)
df_classified.to_csv('DEDuCT_Classified_ChemicalBasicInformation.csv', index=False, sep=',')
